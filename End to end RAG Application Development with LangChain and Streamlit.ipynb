# %% [markdown]
# # File QA RAG Chatbot App with ChatGPT, LangChain and Streamlit
#
# Here we will implement an advanced RAG System with ChatGPT, LangChain and Streamlit to build a File QA UI-based chatbot with the following features:
#
# - PDF Document Upload and Indexing
# - RAG System for query analysis and response
# - Result streaming capabilities (Real-time output)
# - Show document sources of the answer from RAG system

# %% [markdown]
# ## Install App and LLM dependencies

# %%
# !pip install langchain==0.3.11
# !pip install langchain-openai==0.2.12
# !pip install langchain-community==0.3.11
# !pip install streamlit==1.32.2
# !pip install pyngrok==7.2.2
# !pip install PyMuPDF==1.24.0
# !pip install chromadb==0.6.3
# !pip install langchain-chroma==0.2.2
# Out:
# Collecting langchain==0.3.11
#   Using cached langchain-0.3.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (3.11.16)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (0.3.51)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (0.3.8)
# Collecting langsmith<0.3,>=0.1.17 (from langchain==0.3.11)
#   Using cached langsmith-0.2.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (2.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain==0.3.11) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.11) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.11) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.11) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (2.1)
# Requirement already satisfied: sniffio>=1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.3.1)
# Using cached langchain-0.3.11-py3-none-any.whl (1.0 MB)
# Using cached langsmith-0.2.11-py3-none-any.whl (326 kB)
# Installing collected packages: langsmith, langchain
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.23
#     Uninstalling langsmith-0.3.23:
#       Successfully uninstalled langsmith-0.3.23
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.23
#     Uninstalling langchain-0.3.23:
#       Successfully uninstalled langchain-0.3.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.21 requires langchain<1.0.0,>=0.3.23, but you have langchain 0.3.11 which is incompatible.
# langchain-chroma 0.2.2 requires numpy<2.0.0,>=1.26.2; python_version >= "3.12", but you have numpy 2.2.6 which is incompatible.
# embedchain 0.1.128 requires langsmith<0.4.0,>=0.3.18, but you have langsmith 0.2.11 which is incompatible.
# Successfully installed langchain-0.3.11 langsmith-0.2.11
# Collecting langchain-openai==0.2.12
#   Using cached langchain_openai-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-openai==0.2.12) (0.3.51)
# Requirement already satisfied: openai<2.0.0,>=1.55.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-openai==0.2.12) (1.70.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-openai==0.2.12) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (4.15.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.12.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.8.2)
# Requirement already satisfied: sniffio in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in /home/janvi/miniconda3/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.12) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.12) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/janvi/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (3.7)
# Requirement already satisfied: certifi in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.12) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.12) (2.2.3)
# Using cached langchain_openai-0.2.12-py3-none-any.whl (50 kB)
# Installing collected packages: langchain-openai
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.2.14
#     Uninstalling langchain-openai-0.2.14:
#       Successfully uninstalled langchain-openai-0.2.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires langsmith<0.4.0,>=0.3.18, but you have langsmith 0.2.11 which is incompatible.
# Successfully installed langchain-openai-0.2.12
# Collecting langchain-community==0.3.11
#   Using cached langchain_community-0.3.11-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (3.11.16)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.11 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (0.3.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (0.3.51)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (2.2.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (2.8.1)
# Requirement already satisfied: requests<3,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-community==0.3.11) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.11) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.3.11) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.3.11) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.3.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.3.11) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.4.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.3.1)
# Using cached langchain_community-0.3.11-py3-none-any.whl (2.5 MB)
# Installing collected packages: langchain-community
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.21
#     Uninstalling langchain-community-0.3.21:
#       Successfully uninstalled langchain-community-0.3.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires langsmith<0.4.0,>=0.3.18, but you have langsmith 0.2.11 which is incompatible.
# Successfully installed langchain-community-0.3.11
# Collecting streamlit==1.32.2
#   Downloading streamlit-1.32.2-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (8.1.8)
# Collecting numpy<2,>=1.19.3 (from streamlit==1.32.2)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting packaging<24,>=16.8 (from streamlit==1.32.2)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (2.2.2)
# Collecting pillow<11,>=7.1.0 (from streamlit==1.32.2)
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting protobuf<5,>=3.20 (from streamlit==1.32.2)
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=7.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (13.9.4)
# Collecting tenacity<9,>=8.1.0 (from streamlit==1.32.2)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (6.4.2)
# Requirement already satisfied: watchdog>=2.1.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from streamlit==1.32.2) (6.0.0)
# Requirement already satisfied: jinja2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit==1.32.2) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit==1.32.2) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit==1.32.2) (1.33.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.2) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit==1.32.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit==1.32.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit==1.32.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit==1.32.2) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit==1.32.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit==1.32.2) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.2) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit==1.32.2) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (0.24.0)
# Requirement already satisfied: mdurl~=0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.32.2) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit==1.32.2) (1.17.0)
# Downloading streamlit-1.32.2-py2.py3-none-any.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 1.8 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 1.8 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, protobuf, pillow, packaging, numpy, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.44.1
#     Uninstalling streamlit-1.44.1:
#       Successfully uninstalled streamlit-1.44.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.31.0 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# mcp-agent 0.1.17 requires numpy>=2.1.3, but you have numpy 1.26.4 which is incompatible.
# grpcio-tools 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-proto 1.36.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.31.1 requires opentelemetry-exporter-otlp-proto-common==1.31.1, but you have opentelemetry-exporter-otlp-proto-common 1.36.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.31.1 requires opentelemetry-proto==1.31.1, but you have opentelemetry-proto 1.36.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.31.1 requires opentelemetry-sdk~=1.31.1, but you have opentelemetry-sdk 1.36.0 which is incompatible.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.22.0 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.52b1 requires opentelemetry-instrumentation==0.52b1, but you have opentelemetry-instrumentation 0.57b0 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.52b1 requires opentelemetry-semantic-conventions==0.52b1, but you have opentelemetry-semantic-conventions 0.57b0 which is incompatible.
# embedchain 0.1.128 requires langsmith<0.4.0,>=0.3.18, but you have langsmith 0.2.11 which is incompatible.
# opentelemetry-instrumentation-asgi 0.52b1 requires opentelemetry-instrumentation==0.52b1, but you have opentelemetry-instrumentation 0.57b0 which is incompatible.
# opentelemetry-instrumentation-asgi 0.52b1 requires opentelemetry-semantic-conventions==0.52b1, but you have opentelemetry-semantic-conventions 0.57b0 which is incompatible.
# Successfully installed numpy-1.26.4 packaging-23.2 pillow-10.4.0 protobuf-4.25.8 streamlit-1.32.2 tenacity-8.5.0
# Collecting pyngrok==7.2.2
#   Downloading pyngrok-7.2.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: PyYAML>=5.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pyngrok==7.2.2) (6.0.2)
# Downloading pyngrok-7.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.2
# Collecting PyMuPDF==1.24.0
#   Downloading PyMuPDF-1.24.0-cp312-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.0 (from PyMuPDF==1.24.0)
#   Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.0-cp312-none-manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 1.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:01:02
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.0 PyMuPDFb-1.24.0
# Collecting chromadb==0.6.3
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: build>=1.0.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (2.12.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.115.12)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (3.23.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.22.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from chromadb==0.6.3) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb==0.6.3) (23.2)
# Requirement already satisfied: pyproject_hooks in /home/janvi/miniconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb==0.6.3) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb==0.6.3) (0.46.1)
# Requirement already satisfied: anyio in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.6.3) (4.9.0)
# Requirement already satisfied: certifi in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.6.3) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.6.3) (1.0.7)
# Requirement already satisfied: idna in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.6.3) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.6.3) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (1.8.0)
# Requirement already satisfied: requests in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (0.9)
# Requirement already satisfied: coloredlogs in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (25.2.10)
# Requirement already satisfied: protobuf in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (4.25.8)
# Requirement already satisfied: sympy in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.6.3) (8.6.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3) (1.69.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3)
#   Using cached opentelemetry_proto-1.31.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.6.3)
#   Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb==0.6.3)
#   Using cached protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3) (0.52b1)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3) (3.8.1)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.6.3)
#   Using cached opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: monotonic>=1.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.6.3) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.6.3) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.6.3) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==0.6.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==0.6.3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==0.6.3) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==0.6.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==0.6.3) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb==0.6.3) (0.34.4)
# Requirement already satisfied: click>=8.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==0.6.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==0.6.3) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (4.9)
# Requirement already satisfied: filelock in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.6.3) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.6.3) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.6.3) (1.1.9)
# Requirement already satisfied: zipp>=3.20 in /home/janvi/miniconda3/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.6.3) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.6.3) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests->kubernetes>=28.1.0->chromadb==0.6.3) (3.3.2)
# Requirement already satisfied: sniffio>=1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb==0.6.3) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.6.3) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.6.3) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (0.6.1)
# Using cached chromadb-0.6.3-py3-none-any.whl (611 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.31.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl (183 kB)
# Using cached opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
# Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
# Using cached protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: protobuf, opentelemetry-proto, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, opentelemetry-sdk, opentelemetry-instrumentation, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
# ...
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.46.1)
# Requirement already satisfied: anyio in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (4.9.0)
# Requirement already satisfied: certifi in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.0.7)
# Requirement already satisfied: idna in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/janvi/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.2) (2.1)
# Requirement already satisfied: six>=1.9.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.8.0)
# Requirement already satisfied: requests in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /home/janvi/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.2) (1.0.0)
# Requirement already satisfied: coloredlogs in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (25.2.10)
# Requirement already satisfied: protobuf in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (5.29.5)
# Requirement already satisfied: sympy in /home/janvi/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.34.4)
# Requirement already satisfied: click>=8.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/janvi/miniconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (4.9)
# Requirement already satisfied: filelock in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/janvi/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.1.9)
# Requirement already satisfied: zipp>=3.20 in /home/janvi/miniconda3/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/janvi/miniconda3/lib/python3.12/site-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.3.2)
# Requirement already satisfied: sniffio>=1.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/janvi/miniconda3/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/janvi/miniconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.6.1)

# %% [markdown]
# ## Load OpenAI API Credentials
#
# Here we load it from a file so we don't explore the credentials on the internet by mistake

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
import yaml

with open('api_keys.yml', 'r') as file:
    api_creds = yaml.safe_load(file)

# %%
api_creds.keys()
# Out:
# dict_keys(['OPENAI_API_KEY', 'GEMINI_API_KEY', 'NGORK_AUTH_TOKEN', 'DEEPSEEK_API_KEY', 'TOGETHER_API_KEY', 'TAVILY_API_KEY'])

# %%
import os

os.environ['OPENAI_API_KEY'] = api_creds['OPENAI_API_KEY']

# %% [markdown]
# ## Write the app code here and store it in a py file

# %%
# the following line is a magic command
# that will write all the code below it to the python file app.py
# we will then deploy this app.py file on the cloud server where colab is running
# if you have your own server you can just write the code in app.py and deploy it directly
# %%writefile app.py

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.chat_message_histories import StreamlitChatMessageHistory
from langchain_core.callbacks.base import BaseCallbackHandler
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_community.vectorstores.chroma import Chroma
from langchain_chroma import Chroma
from operator import itemgetter
import pandas as pd
import streamlit as st
import chromadb
import tempfile
import os

# Customize initial app landing page
st.set_page_config(page_title="File QA Chatbot", page_icon="🤖")
st.title("Welcome to File QA RAG Chatbot 🤖")

@st.cache_resource(ttl="1h")
# Takes uploaded PDFs, creates document chunks, computes embeddings
# Stores document chunks and embeddings in a Vector DB
# Returns a retriever which can look up the Vector DB
# to return documents based on user input
# Stores this in the cache
def configure_retriever(uploaded_files):
  # Read documents
  docs = []
  temp_dir = tempfile.TemporaryDirectory()
  for file in uploaded_files:
    temp_filepath = os.path.join(temp_dir.name, file.name)
    with open(temp_filepath, "wb") as f:
      f.write(file.getvalue())
    loader = PyMuPDFLoader(temp_filepath)
    docs.extend(loader.load())

  # Split into documents chunks
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500,
                                                 chunk_overlap=200)
  doc_chunks = text_splitter.split_documents(docs)



  # Create document embeddings and store in Vector DB
  embeddings_model = OpenAIEmbeddings()

  client = chromadb.PersistentClient(path="./chroma_db")

  # Use Chroma from LangChain
  vectordb = Chroma.from_documents(
      documents=doc_chunks,
      embedding=embeddings_model,
      client=client,
      collection_name="document_collection"
  )

  # Define retriever object
  retriever = vectordb.as_retriever(search_kwargs={"k": 3})
  return retriever

# Manages live updates to a Streamlit app's display by appending new text tokens
# to an existing text stream and rendering the updated text in Markdown
class StreamHandler(BaseCallbackHandler):
  def __init__(self, container, initial_text=""):
    self.container = container
    self.text = initial_text

  def on_llm_new_token(self, token: str, **kwargs) -> None:
    self.text += token
    self.container.markdown(self.text)

# Creates UI element to accept PDF uploads
uploaded_files = st.sidebar.file_uploader(
  label="Upload PDF files", type=["pdf"],
  accept_multiple_files=True
)
if not uploaded_files:
  st.info("Please upload PDF documents to continue.")
  st.stop()

# Create retriever object based on uploaded PDFs
retriever = configure_retriever(uploaded_files)

# Load a connection to ChatGPT LLM
chatgpt = ChatOpenAI(model_name='gpt-4o-mini', temperature=0.1,
                     streaming=True)

# Create a prompt template for QA RAG System
qa_template = """
              Use only the following pieces of context to answer the question at the end.
              If you don't know the answer, just say that you don't know,
              don't try to make up an answer. Keep the answer as concise as possible.

              {context}

              Question: {question}
              """
qa_prompt = ChatPromptTemplate.from_template(qa_template)

# This function formats retrieved documents before sending to LLM
def format_docs(docs):
  return "\n\n".join([d.page_content for d in docs])

# Create a QA RAG System Chain
qa_rag_chain = (
  {
    "context": itemgetter("question") # based on the user question get context docs
      |
    retriever
      |
    format_docs,
    "question": itemgetter("question") # user question
  }
    |
  qa_prompt # prompt with above user question and context
    |
  chatgpt # above prompt is sent to the LLM for response
)

# Store conversation history in Streamlit session state
streamlit_msg_history = StreamlitChatMessageHistory(key="langchain_messages")

# Shows the first message when app starts
if len(streamlit_msg_history.messages) == 0:
  streamlit_msg_history.add_ai_message("Please ask your question?")

# Render current messages from StreamlitChatMessageHistory
for msg in streamlit_msg_history.messages:
  st.chat_message(msg.type).write(msg.content)

# Callback handler which does some post-processing on the LLM response
# Used to post the top 3 document sources used by the LLM in RAG response
class PostMessageHandler(BaseCallbackHandler):
  def __init__(self, msg: st.write):
    BaseCallbackHandler.__init__(self)
    self.msg = msg
    self.sources = []

  def on_retriever_end(self, documents, *, run_id, parent_run_id, **kwargs):
    source_ids = []
    for d in documents: # retrieved documents from retriever based on user query
      metadata = {
        "source": d.metadata["source"],
        "page": d.metadata["page"],
        "content": d.page_content[:200]
      }
      idx = (metadata["source"], metadata["page"])
      if idx not in source_ids: # store unique source documents
        source_ids.append(idx)
        self.sources.append(metadata)

  def on_llm_end(self, response, *, run_id, parent_run_id, **kwargs):
    if len(self.sources):
      st.markdown("__Sources:__ "+"\n")
      st.dataframe(data=pd.DataFrame(self.sources[:3]),
                    width=1000) # Top 3 sources


# If user inputs a new prompt, display it and show the response
if user_prompt := st.chat_input():
  st.chat_message("human").write(user_prompt)
  # This is where response from the LLM is shown
  with st.chat_message("ai"):
    # Initializing an empty data stream
    stream_handler = StreamHandler(st.empty())
    # UI element to write RAG sources after LLM response
    sources_container = st.write("")
    pm_handler = PostMessageHandler(sources_container)
    config = {"callbacks": [stream_handler, pm_handler]}
    # Get LLM response
    response = qa_rag_chain.invoke({"question": user_prompt},
                                    config)
# Out:
# Writing app.py

# %% [markdown]
# ## Start the app

# %%
# !streamlit run app.py --server.port=8989 &>./logs.txt &

# %%
from pyngrok import ngrok
import yaml

# Terminate open tunnels if exist
ngrok.kill()

# Setting the authtoken
# Get your authtoken from `ngrok_credentials.yml` file
# with open('ngrok_credentials.yml', 'r') as file:
#     NGROK_AUTH_TOKEN = yaml.safe_load(file)
ngrok.set_auth_token(api_creds['NGORK_AUTH_TOKEN'])

# Open an HTTPs tunnel on port XXXX which you get from your `logs.txt` file
ngrok_tunnel = ngrok.connect(8989)
print("Streamlit App:", ngrok_tunnel.public_url)
# Out:
# Streamlit App: https://0f2d-34-23-213-105.ngrok-free.app

# %% [markdown]
# ## Remove running app processes

# %%
ngrok.kill()

# %%
# !ps -ef | grep streamlit
# Out:
# root        1497       1  0 07:11 ?        00:00:09 /usr/bin/python3 /usr/local/bin/streamlit run ap
# root        6975    1320  0 07:34 ?        00:00:00 /bin/bash -c ps -ef | grep streamlit
# root        6977    6975  0 07:34 ?        00:00:00 grep streamlit

# %%
# !sudo kill -9 6975
# Out:
# kill: (6975): No such process
